# %% [markdown]
# <a href="https://colab.research.google.com/github/abdelrahman-rajab-hassan/prediction-of-product-sales/blob/main/prediction_of_product_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project: Prediction of Product Sales
# - Auther: Abdelrahman R J Haasan

# %% [markdown]
# ## Project Overview

# %% [markdown]
# ## Load and Inspect Data

# %% [markdown]
# # Clean Data

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Featuer inspection
